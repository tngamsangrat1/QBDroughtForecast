# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/hohohohia/misc/main/SET_TS_sample.csv')
usdm=pd.read_csv('https://raw.githubusercontent.com/hohohohia/misc/main/USDM_sample.csv')

roff=df.run_off.to_numpy()
evap=df.evaporation.to_numpy()
usdm=usdm.DSCI.to_numpy()

# %%
# roff=roff-np.mean(roff)
# evap=evap-np.mean(evap)

# %%
plt.plot(usdm)

# %%
plt.plot(roff,label='runoff')
plt.plot(evap,label='evaporation')
plt.legend()
plt.show()

# %%
np.corrcoef(roff,evap)
# Out:
# array([[1.        , 0.12116328],
#        [0.12116328, 1.        ]])

# %%
np.corrcoef(roff[:500],usdm[:500])
# Out:
# array([[ 1.        , -0.04559649],
#        [-0.04559649,  1.        ]])
